# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dsc2024 import datasets
from dsc2024 import handling
from dsc2024 import features

# %% [markdown]
# # Data Handling

# %%
# Parameters
sampling = None # None to use everything
real_test = False # cancel sampling!

# %%
# %%time
datasets.dataset_default = "public_f2.csv"
if real_test:
    sampling = None
df = datasets.get_train_dataset(sampling=sampling)
# Out:
# 2024-05-15 02:36:50.473 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149631): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051300 10012KT 9999 FEW021 SCT050 28/24 Q1014=
#                               ^
# 2024-05-15 02:36:50.477 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149639): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051300 10012KT 9999 FEW021 SCT050 28/24 Q1014=
#                               ^
# 2024-05-15 02:36:50.488 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149657): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.496 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149673): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.499 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149678): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.501 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149682): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.502 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149683): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.504 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149686): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.506 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149689): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:50.508 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=149694): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013=
#                               ^
# 2024-05-15 02:36:57.739 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=164460): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR SBFL 221300 17006KT 9999 BKN020 24/16 Q1017=
#                           ^
# 2024-05-15 02:36:57.746 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:57 - Error(row=164474): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | METAR SBFL 221300 17006KT 9999 BKN020 24/16 Q1017=
#                           ^
# 2024-05-15 02:38:04.075 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=48): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-01 07:00:00'))
# 2024-05-15 02:38:04.078 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=53): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-01 07:00:00'))
# 2024-05-15 02:38:04.080 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=55): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-01 07:00:00'))
# 2024-05-15 02:38:04.624 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=823): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-02 07:00:00'))
# 2024-05-15 02:38:04.628 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=827): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-02 07:00:00'))
# 2024-05-15 02:38:05.312 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=1595): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-03 06:00:00'))
# 2024-05-15 02:38:05.316 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=1600): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-03 07:00:00'))
# 2024-05-15 02:38:05.889 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=2406): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-04 06:00:00'))
# 2024-05-15 02:38:05.893 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=2410): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-04 07:00:00'))
# 2024-05-15 02:38:06.406 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=3002): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-05 06:00:00'))
# 2024-05-15 02:38:06.995 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=3707): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-06 06:00:00'))
# 2024-05-15 02:38:07.002 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=3715): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-06 07:00:00'))
# 2024-05-15 02:38:07.624 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=4525): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-07 06:00:00'))
# 2024-05-15 02:38:07.626 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=4527): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-07 07:00:00'))
# 2024-05-15 02:38:08.176 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=5309): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-08 07:00:00'))
# 2024-05-15 02:38:08.179 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=5313): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-08 07:00:00'))
# 2024-05-15 02:38:08.730 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=6094): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-09 06:00:00'))
# 2024-05-15 02:38:08.734 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=6100): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-09 07:00:00'))
# 2024-05-15 02:38:09.316 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=6924): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-10 07:00:00'))
# 2024-05-15 02:38:09.922 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=7771): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-11 07:00:00'))
# 2024-05-15 02:38:09.925 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=7775): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-11 07:00:00'))
# 2024-05-15 02:38:10.370 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=8385): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-12 07:00:00'))
# 2024-05-15 02:38:10.847 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=9076): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-13 07:00:00'))
# 2024-05-15 02:38:10.850 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=9082): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-13 07:00:00'))
# 2024-05-15 02:38:10.853 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=9085): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-13 07:00:00'))
# 2024-05-15 02:38:11.428 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=9920): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-14 06:00:00'))
# 2024-05-15 02:38:11.431 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=9925): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-14 07:00:00'))
# 2024-05-15 02:38:11.988 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=10723): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-15 07:00:00'))
# 2024-05-15 02:38:11.993 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=10728): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-15 07:00:00'))
# 2024-05-15 02:38:12.566 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=11547): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-16 07:00:00'))
# 2024-05-15 02:38:12.570 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=11551): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-16 07:00:00'))
# 2024-05-15 02:38:12.580 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=11558): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-16 07:00:00'))
# 2024-05-15 02:38:13.119 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=12159): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-17 07:00:00'))
# 2024-05-15 02:38:13.553 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=12700): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-18 07:00:00'))
# 2024-05-15 02:38:14.387 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=13893): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-20 07:00:00'))
# 2024-05-15 02:38:14.391 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=13899): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-20 07:00:00'))
# 2024-05-15 02:38:14.958 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=14731): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-21 07:00:00'))
# 2024-05-15 02:38:14.961 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=14734): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-21 07:00:00'))
# 2024-05-15 02:38:15.649 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=15564): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-22 07:00:00'))
# 2024-05-15 02:38:15.651 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=15566): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-22 07:00:00'))
# 2024-05-15 02:38:16.197 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=16370): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-23 07:00:00'))
# 2024-05-15 02:38:16.201 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=16375): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-23 07:00:00'))
# 2024-05-15 02:38:16.764 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=17205): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-24 07:00:00'))
# 2024-05-15 02:38:16.766 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=17208): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-24 07:00:00'))
# 2024-05-15 02:38:16.766 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=17209): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-24 07:00:00'))
# 2024-05-15 02:38:17.322 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=18036): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-25 07:00:00'))
# 2024-05-15 02:38:17.325 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=18040): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-25 07:00:00'))
# 2024-05-15 02:38:17.765 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=18652): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-26 06:00:00'))
# 2024-05-15 02:38:18.282 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=19372): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-27 07:00:00'))
# 2024-05-15 02:38:18.285 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=19376): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-27 07:00:00'))
# 2024-05-15 02:38:18.287 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=19378): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-27 07:00:00'))
# 2024-05-15 02:38:18.878 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=20225): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-28 07:00:00'))
# 2024-05-15 02:38:18.880 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=20227): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-28 07:00:00'))
# 2024-05-15 02:38:19.418 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=21022): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-29 07:00:00'))
# 2024-05-15 02:38:19.422 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=21028): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-29 07:00:00'))
# 2024-05-15 02:38:19.971 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=21835): <class 'KeyError'> - ('SBRJ', Timestamp('2022-06-30 07:00:00'))
# 2024-05-15 02:38:20.537 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=22649): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-01 07:00:00'))
# 2024-05-15 02:38:21.142 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=23512): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-02 07:00:00'))
# 2024-05-15 02:38:21.146 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=23519): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-02 07:00:00'))
# 2024-05-15 02:38:21.581 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=24165): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-03 07:00:00'))
# 2024-05-15 02:38:22.112 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=24915): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-04 07:00:00'))
# 2024-05-15 02:38:22.116 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=24921): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-04 07:00:00'))
# 2024-05-15 02:38:22.697 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=25768): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-05 07:00:00'))
# 2024-05-15 02:38:22.702 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=25774): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-05 07:00:00'))
# 2024-05-15 02:38:23.237 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=26560): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-06 07:00:00'))
# 2024-05-15 02:38:23.241 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=26566): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-06 07:00:00'))
# 2024-05-15 02:38:23.781 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=27363): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-07 07:00:00'))
# 2024-05-15 02:38:23.785 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=27370): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-07 07:00:00'))
# 2024-05-15 02:38:23.786 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=27371): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-07 07:00:00'))
# 2024-05-15 02:38:24.478 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=28209): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-08 07:00:00'))
# 2024-05-15 02:38:24.482 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=28216): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-08 07:00:00'))
# 2024-05-15 02:38:25.070 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=29079): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-09 07:00:00'))
# 2024-05-15 02:38:25.071 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=29080): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-09 07:00:00'))
# 2024-05-15 02:38:25.534 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=29759): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-10 07:00:00'))
# 2024-05-15 02:38:26.045 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=30508): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-11 07:00:00'))
# 2024-05-15 02:38:26.048 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=30511): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-11 07:00:00'))
# 2024-05-15 02:38:26.816 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=31364): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-12 07:00:00'))
# 2024-05-15 02:38:26.819 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=31368): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-12 07:00:00'))
# 2024-05-15 02:38:27.400 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=32182): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-13 07:00:00'))
# 2024-05-15 02:38:27.402 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=32184): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-13 07:00:00'))
# 2024-05-15 02:38:28.017 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=33005): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-14 07:00:00'))
# 2024-05-15 02:38:28.019 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=33007): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-14 07:00:00'))
# 2024-05-15 02:38:28.688 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=33861): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-15 07:00:00'))
# 2024-05-15 02:38:28.689 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=33862): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-15 07:00:00'))
# 2024-05-15 02:38:29.286 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=34733): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-16 07:00:00'))
# 2024-05-15 02:38:29.291 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=34741): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-16 07:00:00'))
# 2024-05-15 02:38:29.758 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=35423): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-17 07:00:00'))
# 2024-05-15 02:38:30.288 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=36184): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-18 07:00:00'))
# 2024-05-15 02:38:30.292 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=36188): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-18 07:00:00'))
# 2024-05-15 02:38:30.937 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=37057): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-19 07:00:00'))
# 2024-05-15 02:38:30.940 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=37061): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-19 07:00:00'))
# 2024-05-15 02:38:30.943 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=37064): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-19 07:00:00'))
# 2024-05-15 02:38:31.560 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=37922): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-20 07:00:00'))
# 2024-05-15 02:38:31.561 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=37923): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-20 07:00:00'))
# 2024-05-15 02:38:32.182 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=38774): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-21 07:00:00'))
# 2024-05-15 02:38:32.184 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=38777): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-21 07:00:00'))
# 2024-05-15 02:38:32.188 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=38781): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-21 07:00:00'))
# 2024-05-15 02:38:32.784 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=39645): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-22 07:00:00'))
# 2024-05-15 02:38:32.788 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=39650): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-22 07:00:00'))
# 2024-05-15 02:38:33.410 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=40532): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-23 07:00:00'))
# 2024-05-15 02:38:33.414 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=40539): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-23 07:00:00'))
# 2024-05-15 02:38:33.415 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=40540): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-23 07:00:00'))
# 2024-05-15 02:38:33.884 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=41223): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-24 07:00:00'))
# 2024-05-15 02:38:34.407 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=41990): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-25 07:00:00'))
# 2024-05-15 02:38:34.410 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=41993): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-25 07:00:00'))
# 2024-05-15 02:38:34.414 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=41999): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-25 07:00:00'))
# 2024-05-15 02:38:35.000 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=42867): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-26 07:00:00'))
# 2024-05-15 02:38:35.003 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=42872): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-26 07:00:00'))
# 2024-05-15 02:38:35.590 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=43716): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-27 07:00:00'))
# 2024-05-15 02:38:35.593 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=43721): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-27 07:00:00'))
# 2024-05-15 02:38:36.157 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=44546): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-28 07:00:00'))
# 2024-05-15 02:38:36.158 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=44548): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-28 07:00:00'))
# 2024-05-15 02:38:36.877 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=45392): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-29 07:00:00'))
# 2024-05-15 02:38:36.879 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=45394): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-29 07:00:00'))
# 2024-05-15 02:38:37.463 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=46256): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-30 07:00:00'))
# 2024-05-15 02:38:37.465 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=46258): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-30 07:00:00'))
# 2024-05-15 02:38:37.932 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=46938): <class 'KeyError'> - ('SBRJ', Timestamp('2022-07-31 07:00:00'))
# 2024-05-15 02:38:38.451 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=47673): <class 'KeyError'> - ('SBRJ', Timestamp('2022-08-01 07:00:00'))
# 2024-05-15 02:38:38.456 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=47681): <class 'KeyError'> - ('SBRJ', Timestamp('2022-08-01 07:00:00'))
# 2024-05-15 02:38:38.458 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=47684): <class 'KeyError'> - ('SBRJ', Timestamp('2022-08-01 07:00:00'))
# 2024-05-15 02:38:38.459 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=47685): <class 'KeyError'> - ('SBRJ', Timestamp('2022-08-01 07:00:00'))
# 2024-05-15 02:39:49.253 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=149542): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | COR SBSV 051300 10012KT 9999 FEW021 SCT050 28/24 Q1014
#                         ^
# 2024-05-15 02:39:49.268 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=149565): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | COR SBSV 051300 10012KT 9999 FEW021 SCT050 28/24 Q1014
#                         ^
# 2024-05-15 02:39:49.274 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=149571): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | COR SBSV 051300 10012KT 9999 FEW021 SCT050 28/24 Q1014
#                         ^
# 2024-05-15 02:39:49.322 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=149631): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013
#                         ^
# 2024-05-15 02:39:49.329 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=149639): <class 'metpy.io._metar_parser.metar_parser.ParseError'> - Line 1: expected one of:
#
#     - [\d] from METAR::datetime
#     - "Z" from METAR::datetime
#
#      1 | COR SBSV 051400 09013KT 9999 VCSH FEW021 SCT050 29/24 Q1013
#                         ^
# 2024-05-15 02:40:36.564 | WARNING  | dsc2024.handling:parse_metar_as_dataframe:46 - Error(row=214023): <class 'KeyError'> - ('SBFL', Timestamp('2023-02-19 11:00:00'))
# CPU times: user 6min, sys: 1.17 s, total: 6min 1s
# Wall time: 6min 1s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211679 entries, 504a62621cd231d6ab67e674ce538cd3 to c962a2267ae4fe0afa4c3542ebdbd403
# Data columns (total 74 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt_dep                         211679 non-null  object
#  1   dt_arr                         211679 non-null  object
#  2   hora_ref                       211679 non-null  datetime64[ns]
#  3   origem                         211679 non-null  object
#  4   destino                        211679 non-null  object
#  5   url_img_satelite               208741 non-null  object
#  6   prev_troca_cabeceira           211679 non-null  int64
#  7   troca_cabeceira_hora_anterior  211679 non-null  int64
#  8   espera                         211679 non-null  float64
#  9   destino_altitude               211679 non-null  int64
#  10  destino_op_diurna              149526 non-null  object
#  11  destino_op_noturna             133082 non-null  object
#  12  destino_comprimento            211679 non-null  int64
#  13  destino_largura                211679 non-null  int64
#  14  destino_superficie             211679 non-null  object
#  15  destino_designacao_left        211679 non-null  object
#  16  destino_designacao_right       211679 non-null  object
#  17  metar_station_id               211667 non-null  object
#  18  metar_latitude                 211667 non-null  float64
#  19  metar_longitude                211667 non-null  float64
#  20  metar_elevation                211667 non-null  float64
#  21  metar_date_time                211517 non-null  datetime64[ns]
#  22  metar_wind_direction           200337 non-null  float64
#  23  metar_wind_speed               211663 non-null  float64
#  24  metar_wind_gust                1972 non-null    float64
#  25  metar_visibility               211649 non-null  float64
#  26  metar_current_wx1              29607 non-null   object
#  27  metar_current_wx2              6289 non-null    object
#  28  metar_current_wx3              27 non-null      object
#  29  metar_skyc1                    151875 non-null  object
#  30  metar_skylev1                  147488 non-null  float64
#  31  metar_skyc2                    86552 non-null   object
#  32  metar_skylev2                  86552 non-null   float64
#  33  metar_skyc3                    26810 non-null   object
#  34  metar_skylev3                  26810 non-null   float64
#  35  metar_skyc4                    1775 non-null    object
#  36  metar_skylev4                  1775 non-null    float64
#  37  metar_cloudcover               211667 non-null  float64
#  38  metar_temperature              211342 non-null  float64
#  39  metar_dewpoint                 210964 non-null  float64
#  40  metar_altimeter                211369 non-null  float64
#  41  metar_current_wx1_symbol       211667 non-null  float64
#  42  metar_current_wx2_symbol       211667 non-null  float64
#  43  metar_current_wx3_symbol       211667 non-null  float64
#  44  metar_remarks                  211667 non-null  object
#  45  metaf_station_id               211553 non-null  object
#  46  metaf_latitude                 211553 non-null  float64
#  47  metaf_longitude                211553 non-null  float64
#  48  metaf_elevation                211553 non-null  float64
#  49  metaf_date_time                211553 non-null  datetime64[ns]
#  50  metaf_wind_direction           204470 non-null  float64
#  51  metaf_wind_speed               211550 non-null  float64
#  52  metaf_wind_gust                917 non-null     float64
#  53  metaf_visibility               211553 non-null  float64
#  54  metaf_current_wx1              42515 non-null   object
#  55  metaf_current_wx2              3760 non-null    object
#  56  metaf_current_wx3              29 non-null      object
#  57  metaf_skyc1                    144371 non-null  object
#  58  metaf_skylev1                  143060 non-null  float64
#  59  metaf_skyc2                    57373 non-null   object
#  60  metaf_skylev2                  57373 non-null   float64
#  61  metaf_skyc3                    19989 non-null   object
#  62  metaf_skylev3                  19989 non-null   float64
#  63  metaf_skyc4                    1453 non-null    object
#  64  metaf_skylev4                  1453 non-null    float64
#  65  metaf_cloudcover               211553 non-null  float64
#  66  metaf_temperature              210515 non-null  float64
#  67  metaf_dewpoint                 210165 non-null  float64
#  68  metaf_altimeter                210530 non-null  float64
#  69  metaf_current_wx1_symbol       211553 non-null  float64
#  70  metaf_current_wx2_symbol       211553 non-null  float64
#  71  metaf_current_wx3_symbol       211553 non-null  float64
#  72  metaf_remarks                  211553 non-null  object
#  73  vector                         211679 non-null  object
# dtypes: datetime64[ns](3), float64(37), int64(5), object(29)
# memory usage: 121.1+ MB

# %%
# drop columns with only has null values
df.dropna(axis=1, how="all", inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211679 entries, 504a62621cd231d6ab67e674ce538cd3 to c962a2267ae4fe0afa4c3542ebdbd403
# Data columns (total 74 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt_dep                         211679 non-null  object
#  1   dt_arr                         211679 non-null  object
#  2   hora_ref                       211679 non-null  datetime64[ns]
#  3   origem                         211679 non-null  object
#  4   destino                        211679 non-null  object
#  5   url_img_satelite               208741 non-null  object
#  6   prev_troca_cabeceira           211679 non-null  int64
#  7   troca_cabeceira_hora_anterior  211679 non-null  int64
#  8   espera                         211679 non-null  float64
#  9   destino_altitude               211679 non-null  int64
#  10  destino_op_diurna              149526 non-null  object
#  11  destino_op_noturna             133082 non-null  object
#  12  destino_comprimento            211679 non-null  int64
#  13  destino_largura                211679 non-null  int64
#  14  destino_superficie             211679 non-null  object
#  15  destino_designacao_left        211679 non-null  object
#  16  destino_designacao_right       211679 non-null  object
#  17  metar_station_id               211667 non-null  object
#  18  metar_latitude                 211667 non-null  float64
#  19  metar_longitude                211667 non-null  float64
#  20  metar_elevation                211667 non-null  float64
#  21  metar_date_time                211517 non-null  datetime64[ns]
#  22  metar_wind_direction           200337 non-null  float64
#  23  metar_wind_speed               211663 non-null  float64
#  24  metar_wind_gust                1972 non-null    float64
#  25  metar_visibility               211649 non-null  float64
#  26  metar_current_wx1              29607 non-null   object
#  27  metar_current_wx2              6289 non-null    object
#  28  metar_current_wx3              27 non-null      object
#  29  metar_skyc1                    151875 non-null  object
#  30  metar_skylev1                  147488 non-null  float64
#  31  metar_skyc2                    86552 non-null   object
#  32  metar_skylev2                  86552 non-null   float64
#  33  metar_skyc3                    26810 non-null   object
#  34  metar_skylev3                  26810 non-null   float64
#  35  metar_skyc4                    1775 non-null    object
#  36  metar_skylev4                  1775 non-null    float64
#  37  metar_cloudcover               211667 non-null  float64
#  38  metar_temperature              211342 non-null  float64
#  39  metar_dewpoint                 210964 non-null  float64
#  40  metar_altimeter                211369 non-null  float64
#  41  metar_current_wx1_symbol       211667 non-null  float64
#  42  metar_current_wx2_symbol       211667 non-null  float64
#  43  metar_current_wx3_symbol       211667 non-null  float64
#  44  metar_remarks                  211667 non-null  object
#  45  metaf_station_id               211553 non-null  object
#  46  metaf_latitude                 211553 non-null  float64
#  47  metaf_longitude                211553 non-null  float64
#  48  metaf_elevation                211553 non-null  float64
#  49  metaf_date_time                211553 non-null  datetime64[ns]
#  50  metaf_wind_direction           204470 non-null  float64
#  51  metaf_wind_speed               211550 non-null  float64
#  52  metaf_wind_gust                917 non-null     float64
#  53  metaf_visibility               211553 non-null  float64
#  54  metaf_current_wx1              42515 non-null   object
#  55  metaf_current_wx2              3760 non-null    object
#  56  metaf_current_wx3              29 non-null      object
#  57  metaf_skyc1                    144371 non-null  object
#  58  metaf_skylev1                  143060 non-null  float64
#  59  metaf_skyc2                    57373 non-null   object
#  60  metaf_skylev2                  57373 non-null   float64
#  61  metaf_skyc3                    19989 non-null   object
#  62  metaf_skylev3                  19989 non-null   float64
#  63  metaf_skyc4                    1453 non-null    object
#  64  metaf_skylev4                  1453 non-null    float64
#  65  metaf_cloudcover               211553 non-null  float64
#  66  metaf_temperature              210515 non-null  float64
#  67  metaf_dewpoint                 210165 non-null  float64
#  68  metaf_altimeter                210530 non-null  float64
#  69  metaf_current_wx1_symbol       211553 non-null  float64
#  70  metaf_current_wx2_symbol       211553 non-null  float64
#  71  metaf_current_wx3_symbol       211553 non-null  float64
#  72  metaf_remarks                  211553 non-null  object
#  73  vector                         211679 non-null  object
# dtypes: datetime64[ns](3), float64(37), int64(5), object(29)
# memory usage: 121.1+ MB

# %%
df = features.create_timedelta_features(df)

# %%
# drop non-feature datetime / image columns (to be out of baseline for feature engineering)
datetime_columns = ["hora_ref", "metaf_date_time", "metar_date_time", "url_img_satelite", "dt_dep", "dt_arr"]
df.drop(columns=datetime_columns, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211679 entries, 504a62621cd231d6ab67e674ce538cd3 to c962a2267ae4fe0afa4c3542ebdbd403
# Data columns (total 70 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   origem                         211679 non-null  object
#  1   destino                        211679 non-null  object
#  2   prev_troca_cabeceira           211679 non-null  int64
#  3   troca_cabeceira_hora_anterior  211679 non-null  int64
#  4   espera                         211679 non-null  float64
#  5   destino_altitude               211679 non-null  int64
#  6   destino_op_diurna              149526 non-null  object
#  7   destino_op_noturna             133082 non-null  object
#  8   destino_comprimento            211679 non-null  int64
#  9   destino_largura                211679 non-null  int64
#  10  destino_superficie             211679 non-null  object
#  11  destino_designacao_left        211679 non-null  object
#  12  destino_designacao_right       211679 non-null  object
#  13  metar_station_id               211667 non-null  object
#  14  metar_latitude                 211667 non-null  float64
#  15  metar_longitude                211667 non-null  float64
#  16  metar_elevation                211667 non-null  float64
#  17  metar_wind_direction           200337 non-null  float64
#  18  metar_wind_speed               211663 non-null  float64
#  19  metar_wind_gust                1972 non-null    float64
#  20  metar_visibility               211649 non-null  float64
#  21  metar_current_wx1              29607 non-null   object
#  22  metar_current_wx2              6289 non-null    object
#  23  metar_current_wx3              27 non-null      object
#  24  metar_skyc1                    151875 non-null  object
#  25  metar_skylev1                  147488 non-null  float64
#  26  metar_skyc2                    86552 non-null   object
#  27  metar_skylev2                  86552 non-null   float64
#  28  metar_skyc3                    26810 non-null   object
#  29  metar_skylev3                  26810 non-null   float64
#  30  metar_skyc4                    1775 non-null    object
#  31  metar_skylev4                  1775 non-null    float64
#  32  metar_cloudcover               211667 non-null  float64
#  33  metar_temperature              211342 non-null  float64
#  34  metar_dewpoint                 210964 non-null  float64
#  35  metar_altimeter                211369 non-null  float64
#  36  metar_current_wx1_symbol       211667 non-null  float64
#  37  metar_current_wx2_symbol       211667 non-null  float64
#  38  metar_current_wx3_symbol       211667 non-null  float64
#  39  metar_remarks                  211667 non-null  object
#  40  metaf_station_id               211553 non-null  object
#  41  metaf_latitude                 211553 non-null  float64
#  42  metaf_longitude                211553 non-null  float64
#  43  metaf_elevation                211553 non-null  float64
#  44  metaf_wind_direction           204470 non-null  float64
#  45  metaf_wind_speed               211550 non-null  float64
#  46  metaf_wind_gust                917 non-null     float64
#  47  metaf_visibility               211553 non-null  float64
#  48  metaf_current_wx1              42515 non-null   object
#  49  metaf_current_wx2              3760 non-null    object
#  50  metaf_current_wx3              29 non-null      object
#  51  metaf_skyc1                    144371 non-null  object
#  52  metaf_skylev1                  143060 non-null  float64
#  53  metaf_skyc2                    57373 non-null   object
#  54  metaf_skylev2                  57373 non-null   float64
#  55  metaf_skyc3                    19989 non-null   object
#  56  metaf_skylev3                  19989 non-null   float64
#  57  metaf_skyc4                    1453 non-null    object
#  58  metaf_skylev4                  1453 non-null    float64
#  59  metaf_cloudcover               211553 non-null  float64
#  60  metaf_temperature              210515 non-null  float64
#  61  metaf_dewpoint                 210165 non-null  float64
#  62  metaf_altimeter                210530 non-null  float64
#  63  metaf_current_wx1_symbol       211553 non-null  float64
#  64  metaf_current_wx2_symbol       211553 non-null  float64
#  65  metaf_current_wx3_symbol       211553 non-null  float64
#  66  metaf_remarks                  211553 non-null  object
#  67  vector                         211679 non-null  object
#  68  hora_do_voo                    211679 non-null  int64
#  69  hora_classe                    211679 non-null  object
# dtypes: float64(37), int64(6), object(27)
# memory usage: 114.7+ MB

# %%
# bad predictor or more than >25% missing values
useless_features = [
    "metar_current_wx3",
    # "metar_skyc4",
    # "metar_skylev4",
    "metaf_current_wx2",
    # "metaf_skylev1",
    # "metaf_skylev2",
    # "metar_skylev3",
    # "metar_skylev4",
    # "metar_wind_gust",
    # "metar_skyc3",
    # "metar_skylev3",
    "hora_do_voo"
]
def drop_useless_features(features):
    features_that_exists = [x for x in useless_features if x in features.columns]
    features.drop(columns=useless_features, inplace=True)
    return features

drop_useless_features(df)
# Out:
#                                  origem destino  prev_troca_cabeceira  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3   SBCF    SBFL                     0
# b0fd0f83644625ecc21f5261e8e5e347   SBPA    SBFL                     0
# 1210f0ca07ddca00d09a3e02d3b100d8   SBSP    SBCF                     0
# b25032f34507cce285ee779446496568   SBGR    SBCT                     0
# 00762a9892ecba7c66d1d87800d38cac   SBSP    SBSV                     0
# ...                                 ...     ...                   ...
# 0a98b5dca235756c6020ae64c1576497   SBCT    SBSP                     0
# 000143522a56fa245543e477c74fd908   SBSP    SBRF                     0
# 1067786192e3ee6942524b8bf3b9e876   SBSP    SBRJ                     0
# dc4e6a72c741c597591f23c558c188f8   SBRJ    SBKP                     0
# c962a2267ae4fe0afa4c3542ebdbd403   SBSV    SBSP                     0
#
#                                   troca_cabeceira_hora_anterior  espera  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3                              1     0.0
# b0fd0f83644625ecc21f5261e8e5e347                              1     0.0
# 1210f0ca07ddca00d09a3e02d3b100d8                              0     0.0
# b25032f34507cce285ee779446496568                              0     0.0
# 00762a9892ecba7c66d1d87800d38cac                              1     0.0
# ...                                                         ...     ...
# 0a98b5dca235756c6020ae64c1576497                              0     0.0
# 000143522a56fa245543e477c74fd908                              0     0.0
# 1067786192e3ee6942524b8bf3b9e876                              0     0.0
# dc4e6a72c741c597591f23c558c188f8                              0     0.0
# c962a2267ae4fe0afa4c3542ebdbd403                              0     0.0
#
#                                   destino_altitude       destino_op_diurna  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3                 5       VFR / IFR - CAT I
# b0fd0f83644625ecc21f5261e8e5e347                 5       VFR / IFR - CAT I
# 1210f0ca07ddca00d09a3e02d3b100d8               829                     NaN
# b25032f34507cce285ee779446496568               911      VFR / IFR - CAT II
# 00762a9892ecba7c66d1d87800d38cac                20       VFR / IFR - CAT I
# ...                                            ...                     ...
# 0a98b5dca235756c6020ae64c1576497               802       VFR / IFR - CAT I
# 000143522a56fa245543e477c74fd908                10                     NaN
# 1067786192e3ee6942524b8bf3b9e876                 3  VFR / IFR Não Precisão
# dc4e6a72c741c597591f23c558c188f8               661                     NaN
# c962a2267ae4fe0afa4c3542ebdbd403               802       VFR / IFR - CAT I
#
#                                       destino_op_noturna  destino_comprimento  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3       VFR / IFR - CAT I                 1320
# b0fd0f83644625ecc21f5261e8e5e347       VFR / IFR - CAT I                 1320
# 1210f0ca07ddca00d09a3e02d3b100d8                     NaN                 3600
# b25032f34507cce285ee779446496568      VFR / IFR - CAT II                 2218
# 00762a9892ecba7c66d1d87800d38cac                     NaN                 1518
# ...                                                  ...                  ...
# 0a98b5dca235756c6020ae64c1576497       VFR / IFR - CAT I                 1940
# 000143522a56fa245543e477c74fd908                     NaN                 3007
# 1067786192e3ee6942524b8bf3b9e876  VFR / IFR Não Precisão                 1260
# dc4e6a72c741c597591f23c558c188f8                     NaN                 3240
# c962a2267ae4fe0afa4c3542ebdbd403       VFR / IFR - CAT I                 1940
#
#                                   destino_largura  ... metaf_cloudcover  \
# flightid                                           ...
# 504a62621cd231d6ab67e674ce538cd3               45  ...              6.0
# b0fd0f83644625ecc21f5261e8e5e347               45  ...              6.0
# 1210f0ca07ddca00d09a3e02d3b100d8               45  ...              0.0
# b25032f34507cce285ee779446496568               45  ...              6.0
# 00762a9892ecba7c66d1d87800d38cac               45  ...              2.0
# ...                                           ...  ...              ...
# 0a98b5dca235756c6020ae64c1576497               45  ...              6.0
# 000143522a56fa245543e477c74fd908               45  ...              6.0
# 1067786192e3ee6942524b8bf3b9e876               30  ...              0.0
# dc4e6a72c741c597591f23c558c188f8               45  ...              8.0
# c962a2267ae4fe0afa4c3542ebdbd403               45  ...              6.0
#
#                                  metaf_temperature metaf_dewpoint  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3              13.0            7.0
# b0fd0f83644625ecc21f5261e8e5e347              13.0            7.0
# 1210f0ca07ddca00d09a3e02d3b100d8              21.0           14.0
# b25032f34507cce285ee779446496568              10.0           10.0
# 00762a9892ecba7c66d1d87800d38cac              27.0           21.0
# ...                                            ...            ...
# 0a98b5dca235756c6020ae64c1576497              26.0           18.0
# 000143522a56fa245543e477c74fd908              30.0           23.0
# 1067786192e3ee6942524b8bf3b9e876              29.0           24.0
# dc4e6a72c741c597591f23c558c188f8              26.0           20.0
# c962a2267ae4fe0afa4c3542ebdbd403              26.0           18.0
#
#                                  metaf_altimeter  metaf_current_wx1_symbol  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3       30.150113                       0.0
# b0fd0f83644625ecc21f5261e8e5e347       30.150113                       0.0
# 1210f0ca07ddca00d09a3e02d3b100d8       30.061523                       0.0
# b25032f34507cce285ee779446496568       30.091053                      61.0
# 00762a9892ecba7c66d1d87800d38cac       29.943403                       0.0
# ...                                          ...                       ...
# 0a98b5dca235756c6020ae64c1576497       29.766223                       0.0
# 000143522a56fa245543e477c74fd908       29.854813                       0.0
# 1067786192e3ee6942524b8bf3b9e876       29.677633                       0.0
# dc4e6a72c741c597591f23c558c188f8       29.795753                       0.0
# c962a2267ae4fe0afa4c3542ebdbd403       29.766223                       0.0
#
#                                   metaf_current_wx2_symbol  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3                       0.0
# b0fd0f83644625ecc21f5261e8e5e347                       0.0
# 1210f0ca07ddca00d09a3e02d3b100d8                       0.0
# b25032f34507cce285ee779446496568                       0.0
# 00762a9892ecba7c66d1d87800d38cac                       0.0
# ...                                                    ...
# 0a98b5dca235756c6020ae64c1576497                       0.0
# 000143522a56fa245543e477c74fd908                       0.0
# 1067786192e3ee6942524b8bf3b9e876                       0.0
# dc4e6a72c741c597591f23c558c188f8                       0.0
# c962a2267ae4fe0afa4c3542ebdbd403                       0.0
#
#                                   metaf_current_wx3_symbol  metaf_remarks  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3                       0.0
# b0fd0f83644625ecc21f5261e8e5e347                       0.0
# 1210f0ca07ddca00d09a3e02d3b100d8                       0.0
# b25032f34507cce285ee779446496568                       0.0
# 00762a9892ecba7c66d1d87800d38cac                       0.0
# ...                                                    ...            ...
# 0a98b5dca235756c6020ae64c1576497                       0.0
# 000143522a56fa245543e477c74fd908                       0.0
# 1067786192e3ee6942524b8bf3b9e876                       0.0
# dc4e6a72c741c597591f23c558c188f8                       0.0
# c962a2267ae4fe0afa4c3542ebdbd403                       0.0
#
#                                                                              vector  \
# flightid
# 504a62621cd231d6ab67e674ce538cd3  [-0.230078, 0.3054307, 0.059676476, -0.4976933...
# b0fd0f83644625ecc21f5261e8e5e347  [-0.230078, 0.3054307, 0.059676476, -0.4976933...
# 1210f0ca07ddca00d09a3e02d3b100d8  [-0.230078, 0.3054307, 0.059676476, -0.4976933...
# b25032f34507cce285ee779446496568  [-0.230078, 0.3054307, 0.059676476, -0.4976933...
# 00762a9892ecba7c66d1d87800d38cac  [-0.230078, 0.3054307, 0.059676476, -0.4976933...
# ...                                                                             ...
# 0a98b5dca235756c6020ae64c1576497  [-0.091816105, 0.8501952, -1.5082136, -0.41015...
# 000143522a56fa245543e477c74fd908  [-0.091816105, 0.8501952, -1.5082136, -0.41015...
# 1067786192e3ee6942524b8bf3b9e876  [-0.091816105, 0.8501952, -1.5082136, -0.41015...
# dc4e6a72c741c597591f23c558c188f8  [-0.091816105, 0.8501952, -1.5082136, -0.41015...
# c962a2267ae4fe0afa4c3542ebdbd403  [-0.091816105, 0.8501952, -1.5082136, -0.41015...
#
#                                   hora_classe
# flightid
# 504a62621cd231d6ab67e674ce538cd3    madrugada
# b0fd0f83644625ecc21f5261e8e5e347    madrugada
# 1210f0ca07ddca00d09a3e02d3b100d8    madrugada
# b25032f34507cce285ee779446496568    madrugada
# 00762a9892ecba7c66d1d87800d38cac    madrugada
# ...                                       ...
# 0a98b5dca235756c6020ae64c1576497          dia
# 000143522a56fa245543e477c74fd908          dia
# 1067786192e3ee6942524b8bf3b9e876          dia
# dc4e6a72c741c597591f23c558c188f8          dia
# c962a2267ae4fe0afa4c3542ebdbd403          dia
#
# [211679 rows x 67 columns]

# %%
X = df.drop("espera", axis=1)
y = df.espera.astype(float)

# %%
# Probability density of espera when P(espera > 0)
import seaborn as sns

def plot_y_distribution(y_non_zero, title=None):
    fig, ax = plt.subplots(1, 2, figsize=(14, 4))
    
    # plots
    sns.histplot(y_non_zero, color='white', bins=25, ax=ax[0])
    sns.kdeplot(y_non_zero, ax=ax[1])
    
    # legends
    for axis in ax:
        mean, median = y_non_zero.mean(), y_non_zero.median()
        
        mean_l = axis.axvline(mean, color='r', linestyle='--', label="média")
        median_l = axis.axvline(median, color='black', linestyle='-.', label="mediana")
        axis.legend([mean_l, median_l], [f'    média: {mean:.1f}s', f'mediana: {median:.1f}s'])
        # axis.set_xticks(range(0, y_non_zero.astype(int).max(), 500))

    if title:
        fig.suptitle(title, fontsize=16)
    fig.subplots_adjust(wspace=0.3)
    plt.show()

y_non_zero = y[y > 0]
plot_y_distribution(y_non_zero, title='Distribuição da variável resposta quando espera > 0')

# %%
y_non_zero.describe()
# Out:
# count    3686.000000
# mean      898.751492
# std       670.110191
# min       241.000000
# 25%       451.000000
# 50%       698.000000
# 75%      1091.000000
# max      7137.000000
# Name: espera, dtype: float64

# %%
cat_features = X.select_dtypes(include=['object']).columns.tolist()
embedding_features = ["vector"]
[cat_features.remove(x) for x in embedding_features]
cat_features,embedding_features
# Out:
# (['origem',
#   'destino',
#   'destino_op_diurna',
#   'destino_op_noturna',
#   'destino_superficie',
#   'destino_designacao_left',
#   'destino_designacao_right',
#   'metar_station_id',
#   'metar_current_wx1',
#   'metar_current_wx2',
#   'metar_skyc1',
#   'metar_skyc2',
#   'metar_skyc3',
#   'metar_skyc4',
#   'metar_remarks',
#   'metaf_station_id',
#   'metaf_current_wx1',
#   'metaf_current_wx3',
#   'metaf_skyc1',
#   'metaf_skyc2',
#   'metaf_skyc3',
#   'metaf_skyc4',
#   'metaf_remarks',
#   'hora_classe'],
#  ['vector'])

# %% [markdown]
# # Data Imputation

# %%
# Fill categorical features with unknown class (a new category)
# numerical features will be filled with min-value catboost default strategy
cat_features_fill_map = {f: "UNKNOWN" for f in cat_features}
X.fillna(cat_features_fill_map, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211679 entries, 504a62621cd231d6ab67e674ce538cd3 to c962a2267ae4fe0afa4c3542ebdbd403
# Data columns (total 66 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   origem                         211679 non-null  object
#  1   destino                        211679 non-null  object
#  2   prev_troca_cabeceira           211679 non-null  int64
#  3   troca_cabeceira_hora_anterior  211679 non-null  int64
#  4   destino_altitude               211679 non-null  int64
#  5   destino_op_diurna              211679 non-null  object
#  6   destino_op_noturna             211679 non-null  object
#  7   destino_comprimento            211679 non-null  int64
#  8   destino_largura                211679 non-null  int64
#  9   destino_superficie             211679 non-null  object
#  10  destino_designacao_left        211679 non-null  object
#  11  destino_designacao_right       211679 non-null  object
#  12  metar_station_id               211679 non-null  object
#  13  metar_latitude                 211667 non-null  float64
#  14  metar_longitude                211667 non-null  float64
#  15  metar_elevation                211667 non-null  float64
#  16  metar_wind_direction           200337 non-null  float64
#  17  metar_wind_speed               211663 non-null  float64
#  18  metar_wind_gust                1972 non-null    float64
#  19  metar_visibility               211649 non-null  float64
#  20  metar_current_wx1              211679 non-null  object
#  21  metar_current_wx2              211679 non-null  object
#  22  metar_skyc1                    211679 non-null  object
#  23  metar_skylev1                  147488 non-null  float64
#  24  metar_skyc2                    211679 non-null  object
#  25  metar_skylev2                  86552 non-null   float64
#  26  metar_skyc3                    211679 non-null  object
#  27  metar_skylev3                  26810 non-null   float64
#  28  metar_skyc4                    211679 non-null  object
#  29  metar_skylev4                  1775 non-null    float64
#  30  metar_cloudcover               211667 non-null  float64
#  31  metar_temperature              211342 non-null  float64
#  32  metar_dewpoint                 210964 non-null  float64
#  33  metar_altimeter                211369 non-null  float64
#  34  metar_current_wx1_symbol       211667 non-null  float64
#  35  metar_current_wx2_symbol       211667 non-null  float64
#  36  metar_current_wx3_symbol       211667 non-null  float64
#  37  metar_remarks                  211679 non-null  object
#  38  metaf_station_id               211679 non-null  object
#  39  metaf_latitude                 211553 non-null  float64
#  40  metaf_longitude                211553 non-null  float64
#  41  metaf_elevation                211553 non-null  float64
#  42  metaf_wind_direction           204470 non-null  float64
#  43  metaf_wind_speed               211550 non-null  float64
#  44  metaf_wind_gust                917 non-null     float64
#  45  metaf_visibility               211553 non-null  float64
#  46  metaf_current_wx1              211679 non-null  object
#  47  metaf_current_wx3              211679 non-null  object
#  48  metaf_skyc1                    211679 non-null  object
#  49  metaf_skylev1                  143060 non-null  float64
#  50  metaf_skyc2                    211679 non-null  object
#  51  metaf_skylev2                  57373 non-null   float64
#  52  metaf_skyc3                    211679 non-null  object
#  53  metaf_skylev3                  19989 non-null   float64
#  54  metaf_skyc4                    211679 non-null  object
#  55  metaf_skylev4                  1453 non-null    float64
#  56  metaf_cloudcover               211553 non-null  float64
#  57  metaf_temperature              210515 non-null  float64
#  58  metaf_dewpoint                 210165 non-null  float64
#  59  metaf_altimeter                210530 non-null  float64
#  60  metaf_current_wx1_symbol       211553 non-null  float64
#  61  metaf_current_wx2_symbol       211553 non-null  float64
#  62  metaf_current_wx3_symbol       211553 non-null  float64
#  63  metaf_remarks                  211679 non-null  object
#  64  vector                         211679 non-null  object
#  65  hora_classe                    211679 non-null  object
# dtypes: float64(36), int64(5), object(25)
# memory usage: 116.3+ MB

# %% [markdown]
# # Data Split Train/Test

# %%
from sklearn.model_selection import train_test_split
random_state = 42
X_base_train, X_test, y_base_train, y_test = train_test_split(X, y, test_size=0.20, random_state=random_state)
X_train, X_eval, y_train, y_eval = train_test_split(X_base_train, y_base_train, test_size=1/8, random_state=random_state)

# real test -> to submit to kaggle, replace X_test from unlabelled samples and resplit train/eval dataset
# WARNING: in this mode, metrics report and confusion matrix are not reliable, since it trained with all data. So they are not show.
if real_test:
    # TODO: move this data handling to be by default at datasets.get_public_dataset()

    # data handling
    df_real_test = datasets.get_test_dataset()
    back = df_real_test.metaf_current_wx3.copy()
    df_real_test.dropna(axis=1, how="all", inplace=True)
    df_real_test['metaf_current_wx3'] = back
    df_reat_test = features.create_timedelta_features(df_real_test)
    df_real_test.drop(columns=datetime_columns, inplace=True)
    drop_useless_features(df_real_test)
    X_test = df_real_test
    X_test.fillna(cat_features_fill_map, inplace=True)

    # split
    _, X_eval, _, y_eval = train_test_split(X, y, test_size=0.20, random_state=random_state)
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42336 entries, e3363a14bd61af40750f7af41ce1791e to 3f523ec8b1d1b5795269b30eb0772bda
# Data columns (total 66 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   origem                         42336 non-null  object
#  1   destino                        42336 non-null  object
#  2   prev_troca_cabeceira           42336 non-null  int64
#  3   troca_cabeceira_hora_anterior  42336 non-null  int64
#  4   destino_altitude               42336 non-null  int64
#  5   destino_op_diurna              42336 non-null  object
#  6   destino_op_noturna             42336 non-null  object
#  7   destino_comprimento            42336 non-null  int64
#  8   destino_largura                42336 non-null  int64
#  9   destino_superficie             42336 non-null  object
#  10  destino_designacao_left        42336 non-null  object
#  11  destino_designacao_right       42336 non-null  object
#  12  metar_station_id               42336 non-null  object
#  13  metar_latitude                 42333 non-null  float64
#  14  metar_longitude                42333 non-null  float64
#  15  metar_elevation                42333 non-null  float64
#  16  metar_wind_direction           40055 non-null  float64
#  17  metar_wind_speed               42333 non-null  float64
#  18  metar_wind_gust                411 non-null    float64
#  19  metar_visibility               42330 non-null  float64
#  20  metar_current_wx1              42336 non-null  object
#  21  metar_current_wx2              42336 non-null  object
#  22  metar_skyc1                    42336 non-null  object
#  23  metar_skylev1                  29345 non-null  float64
#  24  metar_skyc2                    42336 non-null  object
#  25  metar_skylev2                  17334 non-null  float64
#  26  metar_skyc3                    42336 non-null  object
#  27  metar_skylev3                  5441 non-null   float64
#  28  metar_skyc4                    42336 non-null  object
#  29  metar_skylev4                  357 non-null    float64
#  30  metar_cloudcover               42333 non-null  float64
#  31  metar_temperature              42260 non-null  float64
#  32  metar_dewpoint                 42164 non-null  float64
#  33  metar_altimeter                42272 non-null  float64
#  34  metar_current_wx1_symbol       42333 non-null  float64
#  35  metar_current_wx2_symbol       42333 non-null  float64
#  36  metar_current_wx3_symbol       42333 non-null  float64
#  37  metar_remarks                  42336 non-null  object
#  38  metaf_station_id               42336 non-null  object
#  39  metaf_latitude                 42310 non-null  float64
#  40  metaf_longitude                42310 non-null  float64
#  41  metaf_elevation                42310 non-null  float64
#  42  metaf_wind_direction           40872 non-null  float64
#  43  metaf_wind_speed               42308 non-null  float64
#  44  metaf_wind_gust                191 non-null    float64
#  45  metaf_visibility               42310 non-null  float64
#  46  metaf_current_wx1              42336 non-null  object
#  47  metaf_current_wx3              42336 non-null  object
#  48  metaf_skyc1                    42336 non-null  object
#  49  metaf_skylev1                  28449 non-null  float64
#  50  metaf_skyc2                    42336 non-null  object
#  51  metaf_skylev2                  11395 non-null  float64
#  52  metaf_skyc3                    42336 non-null  object
#  53  metaf_skylev3                  4092 non-null   float64
#  54  metaf_skyc4                    42336 non-null  object
#  55  metaf_skylev4                  301 non-null    float64
#  56  metaf_cloudcover               42310 non-null  float64
#  57  metaf_temperature              42118 non-null  float64
#  58  metaf_dewpoint                 42030 non-null  float64
#  59  metaf_altimeter                42121 non-null  float64
#  60  metaf_current_wx1_symbol       42310 non-null  float64
#  61  metaf_current_wx2_symbol       42310 non-null  float64
#  62  metaf_current_wx3_symbol       42310 non-null  float64
#  63  metaf_remarks                  42336 non-null  object
#  64  vector                         42336 non-null  object
#  65  hora_classe                    42336 non-null  object
# dtypes: float64(36), int64(5), object(25)
# memory usage: 21.6+ MB

# %% [markdown]
# # Add graph Features

# %%
from dsc2024 import features
X_train = features.generate_graph_features(X_train)
X_test = features.graph_features_testdata(X_test, X_train)
X_eval = features.graph_features_testdata(X_eval, X_train)

# %%
X_train.describe().T
# Out:
#                                   count         mean          std  \
# prev_troca_cabeceira           148175.0     0.315343     0.464654
# troca_cabeceira_hora_anterior  148175.0     0.225504     0.417915
# destino_altitude               148175.0   510.954419   413.305505
# destino_comprimento            148175.0  2581.410150   916.831118
# destino_largura                148175.0    42.871301     5.234435
# metar_latitude                 148167.0   -21.575239     5.249459
# metar_longitude                148167.0   -45.423260     3.892660
# metar_elevation                148167.0   511.587837   413.196205
# metar_wind_direction           140236.0   158.536538    98.116078
# metar_wind_speed               148163.0     7.032377     3.786399
# metar_wind_gust                  1373.0    25.394028     5.813540
# metar_visibility               148155.0  9416.671466  1626.983844
# metar_skylev1                  103334.0  2156.894149  1212.513200
# metar_skylev2                   60472.0  4656.022622  3036.479891
# metar_skylev3                   18693.0  6539.036003  2890.111181
# metar_skylev4                    1249.0  7987.750200  2011.792673
# metar_cloudcover               148167.0     3.716010     2.915267
# metar_temperature              147940.0    21.669630     5.105652
# metar_dewpoint                 147700.0    16.010515     4.620975
# metar_altimeter                147954.0    30.026745     0.154722
# metar_current_wx1_symbol       148167.0    15.587135   107.163444
# metar_current_wx2_symbol       148167.0     0.387036     2.592772
# metar_current_wx3_symbol       148167.0     0.002902     0.303242
# metaf_latitude                 148091.0   -21.580194     5.237438
# metaf_longitude                148091.0   -45.412993     3.886349
# metaf_elevation                148091.0   509.819604   413.464427
# metaf_wind_direction           143199.0   163.031935   100.830007
# metaf_wind_speed               148090.0     6.981768     3.643924
# metaf_wind_gust                   636.0    25.301887     5.518478
# metaf_visibility               148091.0  8943.158254  2397.098949
# metaf_skylev1                  100277.0  2476.086241  1035.161169
# metaf_skylev2                   40235.0  4963.086865  2948.545907
# metaf_skylev3                   13900.0  6935.474820  2769.083494
# metaf_skylev4                    1021.0  8177.571009  1935.331044
# metaf_cloudcover               148091.0     3.702089     3.037085
# metaf_temperature              147338.0    22.144233     5.066452
# metaf_dewpoint                 147109.0    15.475131     4.920906
# metaf_altimeter                147350.0    29.996231     0.169556
# metaf_current_wx1_symbol       148091.0    23.612205   138.512075
# metaf_current_wx2_symbol       148091.0     0.252385     2.308900
# metaf_current_wx3_symbol       148091.0     0.004025     0.381219
# betwenness                     148175.0     0.007877     0.000392
# flow_betweenness_topo          148175.0     0.017025     0.000644
# edge_connectivity              148175.0    10.616332     0.486280
# deg_diff                       148175.0     0.001228     1.071662
# gmatrix                        148175.0     0.147581     0.076540
#
#                                        min          25%          50%  \
# prev_troca_cabeceira              0.000000     0.000000     0.000000
# troca_cabeceira_hora_anterior     0.000000     0.000000     0.000000
# destino_altitude                  3.000000     9.000000   750.000000
# destino_comprimento            1260.000000  1940.000000  3007.000000
# destino_largura                  30.000000    45.000000    45.000000
# metar_latitude                  -30.000000   -23.620000   -23.000000
# metar_longitude                 -51.170000   -47.920000   -46.630000
# metar_elevation                   3.000000     5.000000   750.000000
# metar_wind_direction              0.000000    90.000000   140.000000
# metar_wind_speed                  0.000000     4.000000     7.000000
# metar_wind_gust                  14.000000    22.000000    25.000000
# metar_visibility                 50.000000  9999.000000  9999.000000
# metar_skylev1                     0.000000  1100.000000  2000.000000
# metar_skylev2                   200.000000  2100.000000  4000.000000
# metar_skylev3                   500.000000  4000.000000  7000.000000
# metar_skylev4                  2300.000000  7000.000000  8000.000000
# metar_cloudcover                  0.000000     0.000000     4.000000
# metar_temperature                 1.000000    18.000000    22.000000
# metar_dewpoint                   -7.000000    13.000000    17.000000
# metar_altimeter                   2.982528    29.943403    30.031993
# metar_current_wx1_symbol          0.000000     0.000000     0.000000
# metar_current_wx2_symbol          0.000000     0.000000     0.000000
# metar_current_wx3_symbol          0.000000     0.000000     0.000000
# metaf_latitude                  -30.000000   -23.620000   -23.000000
# metaf_longitude                 -51.170000   -47.920000   -46.630000
# metaf_elevation                   3.000000     5.000000   750.000000
# metaf_wind_direction              0.000000    90.000000   140.000000
# metaf_wind_speed                  0.000000     4.000000     7.000000
# metaf_wind_gust                  14.000000    22.000000    26.000000
# metaf_visibility                100.000000  9999.000000  9999.000000
# metaf_skylev1                     0.000000  1800.000000  2500.000000
# metaf_skylev2                   200.000000  2500.000000  4000.000000
# metaf_skylev3                   900.000000  4500.000000  7000.000000
# metaf_skylev4                  2300.000000  7000.000000  8000.000000
# metaf_cloudcover                  0.000000     0.000000     4.000000
# metaf_temperature                 1.000000    19.000000    23.000000
# metaf_dewpoint                   -6.000000    12.000000    16.000000
# metaf_altimeter                   2.982528    29.913873    30.002463
# metaf_current_wx1_symbol          0.000000     0.000000     0.000000
# metaf_current_wx2_symbol          0.000000     0.000000     0.000000
# metaf_current_wx3_symbol          0.000000     0.000000     0.000000
# betwenness                        0.007576     0.007576     0.007576
# flow_betweenness_topo             0.016667     0.016667     0.016667
# edge_connectivity                10.000000    10.000000    11.000000
# deg_diff                         -2.000000    -1.000000     0.000000
# gmatrix                           0.012835     0.094541     0.121279
#
#                                         75%           max
# prev_troca_cabeceira               1.000000      1.000000
# troca_cabeceira_hora_anterior      0.000000      1.000000
# destino_altitude                 829.000000   1066.000000
# destino_comprimento             3240.000000   4000.000000
# destino_largura                   45.000000     45.000000
# metar_latitude                   -19.630000     -8.130000
# metar_longitude                  -43.170000    -34.920000
# metar_elevation                  828.000000   1061.000000
# metar_wind_direction             210.000000    360.000000
# metar_wind_speed                   9.000000     35.000000
# metar_wind_gust                   29.000000     45.000000
# metar_visibility               10000.000000  10000.000000
# metar_skylev1                   3000.000000   9000.000000
# metar_skylev2                   7000.000000  10000.000000
# metar_skylev3                  10000.000000  10000.000000
# metar_skylev4                  10000.000000  10000.000000
# metar_cloudcover                   6.000000     10.000000
# metar_temperature                 26.000000     38.000000
# metar_dewpoint                    20.000000     26.000000
# metar_altimeter                   30.120583     30.534003
# metar_current_wx1_symbol           0.000000   1097.000000
# metar_current_wx2_symbol           0.000000     61.000000
# metar_current_wx3_symbol           0.000000     41.000000
# metaf_latitude                   -19.630000     -8.130000
# metaf_longitude                  -43.170000    -34.920000
# metaf_elevation                  828.000000   1061.000000
# metaf_wind_direction             250.000000    360.000000
# metaf_wind_speed                   9.000000     35.000000
# metaf_wind_gust                   29.000000     44.000000
# metaf_visibility               10000.000000  10000.000000
# metaf_skylev1                   3300.000000   9000.000000
# metaf_skylev2                   7000.000000  10000.000000
# metaf_skylev3                  10000.000000  10000.000000
# metaf_skylev4                  10000.000000  10000.000000
# metaf_cloudcover                   6.000000     10.000000
# metaf_temperature                 26.000000     39.000000
# metaf_dewpoint                    19.000000     26.000000
# metaf_altimeter                   30.091053     32.217212
# metaf_current_wx1_symbol           0.000000   1097.000000
# metaf_current_wx2_symbol           0.000000     63.000000
# metaf_current_wx3_symbol           0.000000     41.000000
# betwenness                         0.008333      0.009091
# flow_betweenness_topo              0.016667      0.018182
# edge_connectivity                 11.000000     11.000000
# deg_diff                           1.000000      2.000000
# gmatrix                            0.204983      0.326851

# %% [markdown]
# # Training model

# %%
# %%time
from catboost import CatBoostRegressor, Pool

# Criação do Pool com os dados de treinamento
train_data = Pool(
   data=X_train,
   label=y_train,
   cat_features=cat_features,
   embedding_features=embedding_features
)

# Métrica de avaliação
eval_metric = "R2" 
loss_function = "RMSE"
metric = "R2"  # R-quadrado como métrica de perda personalizada

# Configuração e treinamento do modelo CatBoostRegressor
model = CatBoostRegressor(
    iterations=1000,  
    early_stopping_rounds=50,  # Número de iterações para aguardar uma melhoria
    eval_metric=eval_metric, # Métrica de avaliação para early stopping
    loss_function=loss_function, 
    cat_features=cat_features,
    embedding_features=embedding_features,
    custom_metric=[metric],  # Métrica personalizada adicional
    verbose=50,  # Exibir informações a cada n iterações
    random_seed=random_state,
    bagging_temperature=10,
    use_best_model=True,
    depth=16 -1,  # Profundidade máxima das árvores
    learning_rate=0.004,
    subsample=0.8,
)

# Treinamento do modelo
model.fit(train_data, eval_set=(X_eval, y_eval), plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.0007698	test: 0.0005777	best: 0.0005777 (0)	total: 1.58s	remaining: 26m 21s
# 50:	learn: 0.0384183	test: 0.0252409	best: 0.0252409 (50)	total: 1m 51s	remaining: 34m 32s
# 100:	learn: 0.0710148	test: 0.0448413	best: 0.0448413 (100)	total: 3m 35s	remaining: 31m 55s
# 150:	learn: 0.0991418	test: 0.0595200	best: 0.0595200 (150)	total: 5m 34s	remaining: 31m 21s
# 200:	learn: 0.1218562	test: 0.0701767	best: 0.0701767 (200)	total: 7m 33s	remaining: 30m 4s
# 250:	learn: 0.1427194	test: 0.0790029	best: 0.0790029 (250)	total: 9m 20s	remaining: 27m 53s
# 300:	learn: 0.1604105	test: 0.0868597	best: 0.0868597 (300)	total: 11m 15s	remaining: 26m 9s
# 350:	learn: 0.1754998	test: 0.0935231	best: 0.0935231 (350)	total: 13m 13s	remaining: 24m 26s
# 400:	learn: 0.1869821	test: 0.0973383	best: 0.0973383 (400)	total: 15m 20s	remaining: 22m 54s
# 450:	learn: 0.1980484	test: 0.1009851	best: 0.1009851 (450)	total: 17m 20s	remaining: 21m 6s
# 500:	learn: 0.2051348	test: 0.1036128	best: 0.1036130 (499)	total: 19m 12s	remaining: 19m 8s
# 550:	learn: 0.2124722	test: 0.1057814	best: 0.1057814 (550)	total: 21m 6s	remaining: 17m 12s
# 600:	learn: 0.2188023	test: 0.1079811	best: 0.1079811 (600)	total: 22m 52s	remaining: 15m 11s
# 650:	learn: 0.2232537	test: 0.1090830	best: 0.1090830 (650)	total: 24m 47s	remaining: 13m 17s
# 700:	learn: 0.2272804	test: 0.1104948	best: 0.1104948 (700)	total: 26m 39s	remaining: 11m 22s
# 750:	learn: 0.2311409	test: 0.1114781	best: 0.1114781 (750)	total: 28m 41s	remaining: 9m 30s
# 800:	learn: 0.2350710	test: 0.1126705	best: 0.1126705 (800)	total: 30m 54s	remaining: 7m 40s
# 850:	learn: 0.2385801	test: 0.1136962	best: 0.1136962 (850)	total: 32m 47s	remaining: 5m 44s
# 900:	learn: 0.2427581	test: 0.1148277	best: 0.1148277 (900)	total: 35m 2s	remaining: 3m 51s
# 950:	learn: 0.2454075	test: 0.1157246	best: 0.1157246 (950)	total: 36m 48s	remaining: 1m 53s
# 999:	learn: 0.2479717	test: 0.1165072	best: 0.1165072 (999)	total: 38m 13s	remaining: 0us
#
# bestTest = 0.1165072389
# bestIteration = 999
#
# CPU times: user 4h 15min 12s, sys: 5min 19s, total: 4h 20min 32s
# Wall time: 41min 35s

# %%
y_pred = model.predict(X_test[model.feature_names_])
y_pred_series = pd.Series(y_pred, index=X_test.index, name="espera")

# %%
y_pred
# Out:
# array([25.8509496 ,  7.33364596, 31.5847582 , ...,  7.22668861,
#        14.61594179, 35.85470848])

# %% [markdown]
# # Model evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, r2_score

def display_model_evaluation(y_test, y_pred):
    report = classification_report(y_test, y_pred)
    f1_score_class1 = f1_score(y_test, y_pred, average=None)
    print(f"Classification Report: F1[class=1] = {round(f1_score_class1[1], 3)}")
    print(report)
    
    # Print confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

def regression_report(y_test, y_pred):
    print("R2 score: ", round(r2_score(y_test, y_pred), ndigits=3))

if not real_test:
    t = y_train[y_train > 0].min()
    y_test_binarized = (y_test > t).astype(int)
    y_pred_binarized =  (y_pred > t).astype(int)
    regression_report(y_test, y_pred)
    display_model_evaluation(y_test_binarized, y_pred_binarized)
    plot_y_distribution(y_test[y_test > t], title=f'Distribuição de y_test quando espera > {t}')
    plot_y_distribution(y_pred_series[y_pred_series > t], title=f'Distribuição de y_pred quando espera > {t}')
# Out:
# R2 score:  0.096
# Classification Report: F1[class=1] = 0.139
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     41616
#            1       0.52      0.08      0.14       720
#
#     accuracy                           0.98     42336
#    macro avg       0.75      0.54      0.57     42336
# weighted avg       0.98      0.98      0.98     42336
#
# Confusion Matrix:
# [[41562    54]
#  [  662    58]]

# %%
# plot feature importance
feature_importance = model.get_feature_importance(type='FeatureImportance')
feature_names = model.feature_names_
sorted_idx = feature_importance.argsort()

plt.figure(figsize=(8, 13))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), [feature_names[i] for i in sorted_idx])
plt.xlabel('Feature Importance')
plt.title('CatBoost Feature Importance')
plt.show()

# %% [markdown]
# # Save prediction

# %%
if real_test:
    y_pred_series.to_csv(datasets.datasets_dir / "catboost_regression.csv")
    y_pred_series.count()
