# %%
from dsc2024 import datasets
from dsc2024 import handling

# %%
df = datasets.get_public_dataset()
# sampling
# df = df.sample(n=10000, replace='False')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302399 entries, 0 to 302398
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   flightid                       302399 non-null  object
#  1   hora_ref                       302399 non-null  datetime64[ns]
#  2   origem                         302399 non-null  object
#  3   destino                        302399 non-null  object
#  4   url_img_satelite               298666 non-null  object
#  5   metaf                          155737 non-null  object
#  6   metar                          300770 non-null  object
#  7   prev_troca_cabeceira           302399 non-null  int64
#  8   troca_cabeceira_hora_anterior  302399 non-null  int64
#  9   espera                         211679 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 23.1+ MB

# %%
df.head()
# Out:
#                            flightid            hora_ref origem destino  \
# 0  504a62621cd231d6ab67e674ce538cd3 2022-06-01 01:00:00   SBCF    SBFL
# 1  b0fd0f83644625ecc21f5261e8e5e347 2022-06-01 01:00:00   SBPA    SBFL
# 2  1210f0ca07ddca00d09a3e02d3b100d8 2022-06-01 01:00:00   SBSP    SBCF
# 3  b25032f34507cce285ee779446496568 2022-06-01 01:00:00   SBGR    SBCT
# 4  00762a9892ecba7c66d1d87800d38cac 2022-06-01 01:00:00   SBSP    SBSV
#
#                                     url_img_satelite metaf  \
# 0  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 1  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 2  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 3  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 4  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
#
#                                                metar  prev_troca_cabeceira  \
# 0  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# ...

# %%
df_sampling = df.sample(1000)

# %%
df_sampling
# Out:
#                                 flightid            hora_ref origem destino  \
# 189613  7007abf1ec01b4dcc0e9c4998d179e3f 2023-01-21 20:00:00   SBSV    SBGR
# 233656  bd107a572472203210898165abe3d88c 2023-03-14 22:00:00   SBCF    SBSP
# 218845  0175851be0e28b42d69bd3cc6f478464 2023-02-25 16:00:00   SBRF    SBSP
# 122830  2b198fd5732afdb41b75c9fa6e969bb7 2022-11-03 22:00:00   SBBR    SBGR
# 101869  99a801852d6fa7403c44e0e3383354a8 2022-10-08 16:00:00   SBKP    SBCF
# ...                                  ...                 ...    ...     ...
# 109151  8a549a6f93799a40a7108b50fcaadfc8 2022-10-18 11:00:00   SBBR    SBRJ
# 22716   4c9e29ecb64c38ac21030d735403d655 2022-07-01 09:00:00   SBSP    SBRJ
# 243231  7f2c8182d79c658c7de39050f2fd10a7 2023-03-26 11:00:00   SBSV    SBRF
# 262884  5041d8c214c5a5e3dadfab99cb9da88d 2023-04-17 13:00:00   SBBR    SBRJ
# 126210  2ecaf20a9a737b1ae8ddae63764e03d5 2022-11-08 00:00:00   SBBR    SBKP
#
# ...

# %%
handling.parse_metar_as_dataframe(df_sampling, metar_column="metaf")
# Out:
#        station_id  latitude  longitude  elevation           date_time  \
# 189613       SBGR    -23.42     -46.47      750.0 2023-01-21 20:00:00
# 233656       SBSP    -23.62     -46.63      803.0 2023-03-14 22:00:00
# 218845       SBSP    -23.62     -46.63      803.0 2023-02-25 16:00:00
# 122830       SBGR    -23.42     -46.47      750.0 2022-11-03 22:00:00
# 101869       None       NaN        NaN        NaN                 NaT
# ...           ...       ...        ...        ...                 ...
# 109151       None       NaN        NaN        NaN                 NaT
# 22716        None       NaN        NaN        NaN                 NaT
# 243231       None       NaN        NaN        NaN                 NaT
# 262884       SBRJ    -22.88     -43.17        3.0 2023-04-17 13:00:00
# 126210       SBKP    -23.00     -47.12      661.0 2022-11-08 00:00:00
#
#         wind_direction  wind_speed  wind_gust  visibility current_wx1  ...  \
# ...

# %%
handling.parse_metar_as_dataframe(df_sampling, metar_column="metar")
# Out:
#        station_id  latitude  longitude  elevation           date_time  \
# 189613       SBGR    -23.42     -46.47      750.0 2023-01-21 19:00:00
# 233656       SBSP    -23.62     -46.63      803.0 2023-03-14 21:00:00
# 218845       SBSP    -23.62     -46.63      803.0 2023-02-25 15:00:00
# 122830       SBGR    -23.42     -46.47      750.0 2022-11-03 21:00:00
# 101869       SBCF    -19.63     -43.97      828.0 2022-10-08 15:00:00
# ...           ...       ...        ...        ...                 ...
# 109151       SBRJ    -22.88     -43.17        3.0 2022-10-18 10:00:00
# 22716        None       NaN        NaN        NaN                 NaT
# 243231       SBRF     -8.13     -34.92       19.0 2023-03-26 10:00:00
# 262884       SBRJ    -22.88     -43.17        3.0 2023-04-17 12:00:00
# 126210       SBKP    -23.00     -47.12      661.0 2022-11-07 23:00:00
#
#         wind_direction  wind_speed  wind_gust  visibility current_wx1  ...  \
# ...
