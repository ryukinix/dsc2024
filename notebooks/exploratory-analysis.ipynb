# %%
from dsc2024 import datasets

# %%
df = datasets.get_public_dataset()
# sampling
# df = df.sample(n=10000, replace='False')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302399 entries, 0 to 302398
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   flightid                       302399 non-null  object
#  1   hora_ref                       302399 non-null  object
#  2   origem                         302399 non-null  object
#  3   destino                        302399 non-null  object
#  4   url_img_satelite               298666 non-null  object
#  5   metaf                          155737 non-null  object
#  6   metar                          300770 non-null  object
#  7   prev_troca_cabeceira           302399 non-null  int64
#  8   troca_cabeceira_hora_anterior  302399 non-null  int64
#  9   espera                         211679 non-null  float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 23.1+ MB

# %%
df.head()
# Out:
#                            flightid              hora_ref origem destino  \
# 0  504a62621cd231d6ab67e674ce538cd3  2022-06-01T01:00:00Z   SBCF    SBFL
# 1  b0fd0f83644625ecc21f5261e8e5e347  2022-06-01T01:00:00Z   SBPA    SBFL
# 2  1210f0ca07ddca00d09a3e02d3b100d8  2022-06-01T01:00:00Z   SBSP    SBCF
# 3  b25032f34507cce285ee779446496568  2022-06-01T01:00:00Z   SBGR    SBCT
# 4  00762a9892ecba7c66d1d87800d38cac  2022-06-01T01:00:00Z   SBSP    SBSV
#
#                                     url_img_satelite metaf  \
# 0  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 1  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 2  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 3  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 4  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
#
#                                                metar  prev_troca_cabeceira  \
# 0  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# ...

# %%
from metpy import io
# ref: https://unidata.github.io/MetPy/latest/api/generated/metpy.io.parse_metar_to_dataframe.html
df_metar = io.metar._metars_to_dataframe(df['metar'].dropna().to_list())
df_metar
# Out:
#            station_id  latitude  longitude  elevation           date_time  \
# station_id
# SBKP             SBKP    -23.00     -47.12        661 2024-04-01 06:00:00
# SBPA             SBPA    -30.00     -51.17          3 2024-04-02 03:00:00
# SBSV             SBSV    -12.90     -38.32          6 2024-04-02 07:00:00
# SBPA             SBPA    -30.00     -51.17          3 2024-04-03 22:00:00
# SBFL             SBFL    -27.67     -48.53          5 2024-04-04 22:00:00
# ...               ...       ...        ...        ...                 ...
# SBGR             SBGR    -23.42     -46.47        750                 NaT
# SBCT             SBCT    -25.52     -49.17        908                 NaT
# SBSP             SBSP    -23.62     -46.63        803                 NaT
# SBKP             SBKP    -23.00     -47.12        661                 NaT
# SBRJ             SBRJ    -22.88     -43.17          3                 NaT
#
# ...

# %%
io.parse_metar_to_dataframe(df['metaf'].dropna().iloc[0].replace('METAF', 'METAR'))
# Out:
#            station_id  latitude  longitude  elevation           date_time  \
# station_id
# SBGR             SBGR    -23.42     -46.47        750 2024-04-01 01:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# SBGR                   110         8.0        NaN        1000          BR
#
#             ...  air_temperature  dew_point_temperature altimeter  \
# station_id  ...
# SBGR        ...             15.0                   14.0     30.06
#
#             current_wx1_symbol  current_wx2_symbol  current_wx3_symbol  \
# station_id
# SBGR                        10                   0                   0
#
#             remarks  air_pressure_at_sea_level  eastward_wind  northward_wind
# station_id
# SBGR                                   1017.59      -7.517541        2.736161
#
# [1 rows x 31 columns]

# %%
df['metaf'].dropna().iloc[0].replace('METAF', 'METAR')
# Out:
# 'METAR SBGR 010100Z  11008KT 1000     BR OVC033   15/14 Q1018= '

# %%
df['metar'].dropna().iloc[0]
# Out:
# 'METAR SBFL 010000Z 17009KT 140V200 9999 BKN030 14/07 Q1020='

# %%
# metaf -> metar
#
