# %%
from dsc2024 import datasets
from dsc2024 import handling

# %%
df_base = datasets.get_public_dataset(expand_metar_and_metaf=False)

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302399 entries, 0 to 302398
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   flightid                       302399 non-null  object
#  1   hora_ref                       302399 non-null  datetime64[ns]
#  2   origem                         302399 non-null  object
#  3   destino                        302399 non-null  object
#  4   url_img_satelite               298666 non-null  object
#  5   metaf                          155737 non-null  object
#  6   metar                          300770 non-null  object
#  7   prev_troca_cabeceira           302399 non-null  int64
#  8   troca_cabeceira_hora_anterior  302399 non-null  int64
#  9   espera                         211679 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 23.1+ MB

# %%
df_base.head()
# Out:
#                            flightid            hora_ref origem destino  \
# 0  504a62621cd231d6ab67e674ce538cd3 2022-06-01 01:00:00   SBCF    SBFL
# 1  b0fd0f83644625ecc21f5261e8e5e347 2022-06-01 01:00:00   SBPA    SBFL
# 2  1210f0ca07ddca00d09a3e02d3b100d8 2022-06-01 01:00:00   SBSP    SBCF
# 3  b25032f34507cce285ee779446496568 2022-06-01 01:00:00   SBGR    SBCT
# 4  00762a9892ecba7c66d1d87800d38cac 2022-06-01 01:00:00   SBSP    SBSV
#
#                                     url_img_satelite metaf  \
# 0  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 1  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 2  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 3  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 4  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
#
#                                                metar  prev_troca_cabeceira  \
# 0  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# ...

# %%
df_train = datasets.get_train_dataset()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6991 entries, 54455 to 40144
# Data columns (total 64 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   flightid                       6991 non-null   object
#  1   hora_ref                       6991 non-null   datetime64[ns]
#  2   origem                         6991 non-null   object
#  3   destino                        6991 non-null   object
#  4   url_img_satelite               6899 non-null   object
#  5   prev_troca_cabeceira           6991 non-null   int64
#  6   troca_cabeceira_hora_anterior  6991 non-null   int64
#  7   espera                         6991 non-null   float64
#  8   metar_station_id               6942 non-null   object
#  9   metar_latitude                 6942 non-null   float64
#  10  metar_longitude                6942 non-null   float64
#  11  metar_elevation                6942 non-null   float64
# ...

# %%
df_train.head()
# Out:
#                                 flightid            hora_ref origem destino  \
# 54455   5fa9a19e5f54651b2efa9228f0b90f70 2022-08-09 15:00:00   SBSP    SBCT
# 105182  ce6b915353862b0045c102fb6678f589 2022-10-13 10:00:00   SBGL    SBGR
# 131129  1a363ebe75c29360effcbc626a17cb39 2022-11-13 19:00:00   SBRJ    SBGR
# 82569   d5b1d305160389ea8331225e8fc2531c 2022-09-14 15:00:00   SBPA    SBKP
# 199409  5b24ab7100c89990b180c6b7fc5def4b 2023-02-02 11:00:00   SBSP    SBFL
#
#                                          url_img_satelite  \
# 54455   http://satelite.cptec.inpe.br/repositoriogoes/...
# 105182  http://satelite.cptec.inpe.br/repositoriogoes/...
# 131129  http://satelite.cptec.inpe.br/repositoriogoes/...
# 82569   http://satelite.cptec.inpe.br/repositoriogoes/...
# 199409  http://satelite.cptec.inpe.br/repositoriogoes/...
#
#         prev_troca_cabeceira  troca_cabeceira_hora_anterior  espera  \
# 54455                      0                              1     0.0
# ...

# %%
df_train
# Out:
#                                 flightid            hora_ref origem destino  \
# 54455   5fa9a19e5f54651b2efa9228f0b90f70 2022-08-09 15:00:00   SBSP    SBCT
# 105182  ce6b915353862b0045c102fb6678f589 2022-10-13 10:00:00   SBGL    SBGR
# 131129  1a363ebe75c29360effcbc626a17cb39 2022-11-13 19:00:00   SBRJ    SBGR
# 82569   d5b1d305160389ea8331225e8fc2531c 2022-09-14 15:00:00   SBPA    SBKP
# 199409  5b24ab7100c89990b180c6b7fc5def4b 2023-02-02 11:00:00   SBSP    SBFL
# ...                                  ...                 ...    ...     ...
# 5071    ba3c7bb64f527960c0ea720a64629075 2022-06-07 20:00:00   SBSV    SBBR
# 79648   c3f7a2d473b6d5fc5917efe8188db6a8 2022-09-10 22:00:00   SBRJ    SBSP
# 31123   c237471ecb0bf18cf7ff3cd3a041b29a 2022-07-11 20:00:00   SBRJ    SBCT
# 175081  dda3f2efc48caa12b12bd35ceac0438b 2023-01-04 18:00:00   SBSP    SBRJ
# 40144   1d3d7c1b320be2723cadf0582c143710 2022-07-22 18:00:00   SBSP    SBRJ
#
# ...

# %%
df_train.origem.value_counts()
# Out:
# origem
# SBSP    1199
# SBRJ     966
# SBGR     878
# SBBR     643
# SBCF     622
# SBKP     554
# SBPA     497
# SBCT     422
# SBRF     387
# SBSV     384
# SBFL     293
# SBGL     146
# Name: count, dtype: int64

# %%
df_train.destino.value_counts()
# Out:
# destino
# SBSP    1158
# SBRJ    1019
# SBGR     806
# SBBR     701
# SBCF     628
# SBPA     545
# SBKP     466
# SBCT     459
# SBSV     416
# SBRF     365
# SBFL     285
# SBGL     143
# Name: count, dtype: int64

# %%
df_train.metaf_date_time
# Out:
# 54455    2022-08-09 15:00:00
# 105182   2022-10-13 10:00:00
# 131129   2022-11-13 19:00:00
# 82569    2022-09-14 15:00:00
# 199409                   NaT
#                  ...
# 5071                     NaT
# 79648    2022-09-10 22:00:00
# 31123                    NaT
# 175081                   NaT
# 40144                    NaT
# Name: metaf_date_time, Length: 6991, dtype: datetime64[ns]

# %%
df_train.metar_date_time
# Out:
# 54455    2022-08-09 14:00:00
# 105182   2022-10-13 09:00:00
# 131129   2022-11-13 18:00:00
# 82569    2022-09-14 14:00:00
# 199409   2023-02-02 10:00:00
#                  ...
# 5071     2022-06-07 19:00:00
# 79648    2022-09-10 21:00:00
# 31123    2022-07-11 19:00:00
# 175081   2023-01-04 17:00:00
# 40144    2022-07-22 17:00:00
# Name: metar_date_time, Length: 6991, dtype: datetime64[ns]

# %%
df_train.hora_ref
# Out:
# 54455    2022-08-09 15:00:00
# 105182   2022-10-13 10:00:00
# 131129   2022-11-13 19:00:00
# 82569    2022-09-14 15:00:00
# 199409   2023-02-02 11:00:00
#                  ...
# 5071     2022-06-07 20:00:00
# 79648    2022-09-10 22:00:00
# 31123    2022-07-11 20:00:00
# 175081   2023-01-04 18:00:00
# 40144    2022-07-22 18:00:00
# Name: hora_ref, Length: 6991, dtype: datetime64[ns]

# %%
# hora_ref, date_time and date_time_metaf are the same
